# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df0 = pd.read_csv("p2pPlot/Node0WaitingTime.csv")
df1 = pd.read_csv("p2pPlot/Node1WaitingTime.csv")
df2 = pd.read_csv("p2pPlot/Node2WaitingTime.csv")
df3 = pd.read_csv("p2pPlot/Node3WaitingTime.csv")
df4 = pd.read_csv("p2pPlot/Node0QueueSize.csv")
df5 = pd.read_csv("p2pPlot/Node1QueueSize.csv")
df6 = pd.read_csv("p2pPlot/Node2QueueSize.csv")
df7 = pd.read_csv("p2pPlot/Node3QueueSize.csv")

# %%
df0
# Out:
#         Time  Waiting Time
# 0   0.006117             0
# 1   0.020000             0
# 2   0.040000             0
# 3   0.060000             0
# 4   0.080000             0
# ..       ...           ...
# 95  1.900000             0
# 96  1.920000             0
# 97  1.940000             0
# 98  1.960000             0
# 99  1.980000             0
#
# [100 rows x 2 columns]

# %%
df0.plot(x='Time', y='Waiting Time', label='Waiting Time of packet at Node 0',title="Waiting Time v/s Time for node 0",ylabel="Waiting Time")
plt.show()

# %%
df1.plot(x='Time', y='Waiting Time', label='Waiting Time of packet at Node 1',title="Waiting Time v/s Time for node 1",ylabel="Waiting Time")
plt.show()

# %%
df2.plot(x='Time', y='Waiting Time', label='Waiting Time of packet at Node 2',title="Waiting Time v/s Time for node 2",ylabel="Waiting Time")
plt.show()

# %%
df3.plot(x='Time', y='Waiting Time', label='Waiting Time of packet at Node 3',title="Waiting Time v/s Time for node 3",ylabel="Waiting Time")
plt.show()

# %%
df4.plot(x='Time', y='Queue Size', label='Queue size at Nodes 0',title="Queue Size v/s Time",ylabel="Queue Size")
plt.show()

# %%
df5.plot(x='Time', y='Queue Size', label='Queue size at Nodes 1',title="Queue Size v/s Time",ylabel="Queue Size")
plt.show()

# %%
df6.plot(x='Time', y='Queue Size', label='Queue size at Nodes 2',title="Queue Size v/s Time",ylabel="Queue Size")
plt.show()

# %%
df7.plot(x='Time', y='Queue Size', label='Queue size at Nodes 3',title="Queue Size v/s Time",ylabel="Queue Size")
plt.show()
